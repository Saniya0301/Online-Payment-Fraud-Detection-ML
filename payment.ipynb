# %%
import pandas as pd
import numpy as np
data = pd.read_csv("/content/onlinefraud[1].csv")
data.head()
# Out:
#    step      type    amount     nameOrig  oldbalanceOrg  newbalanceOrig  \
# 0     1   PAYMENT   9839.64  C1231006815       170136.0       160296.36
# 1     1   PAYMENT   1864.28  C1666544295        21249.0        19384.72
# 2     1  TRANSFER    181.00  C1305486145          181.0            0.00
# 3     1  CASH_OUT    181.00   C840083671          181.0            0.00
# 4     1   PAYMENT  11668.14  C2048537720        41554.0        29885.86
#
#       nameDest  oldbalanceDest  newbalanceDest  isFraud  isFlaggedFraud
# 0  M1979787155             0.0             0.0      0.0             0.0
# 1  M2044282225             0.0             0.0      0.0             0.0
# 2   C553264065             0.0             0.0      1.0             0.0
# 3    C38997010         21182.0             0.0      1.0             0.0
# 4  M1230701703             0.0             0.0      0.0             0.0

# %%
data.isnull().sum()
# Out:
# step              0
# type              0
# amount            0
# nameOrig          1
# oldbalanceOrg     1
# newbalanceOrig    1
# nameDest          1
# oldbalanceDest    1
# newbalanceDest    1
# isFraud           1
# isFlaggedFraud    1
# dtype: int64

# %%
# Exploring transaction type
data.type.value_counts()
# Out:
# type
# PAYMENT     70958
# CASH_OUT    63918
# CASH_IN     39913
# TRANSFER    16165
# DEBIT        1639
# Name: count, dtype: int64

# %%
type = data["type"].value_counts()
transactions = type.index
quantity = type.values

import plotly.express as px
figure = px.pie(data,
             values=quantity,
             names=transactions,hole = 0.5,
             title="Distribution of Transaction Type")
figure.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
# Checking correlation
# Drop non-numeric columns and rows with NaN values before calculating correlation
numeric_data = data.drop(columns=['type', 'nameOrig', 'nameDest']).dropna()
correlation = numeric_data.corr()
print(correlation["isFraud"].sort_values(ascending=False))
# Out:
# isFraud           1.000000
# amount            0.034266
# oldbalanceOrg    -0.002900
# newbalanceDest   -0.005323
# oldbalanceDest   -0.008207
# newbalanceOrig   -0.008508
# step             -0.040786
# isFlaggedFraud         NaN
# Name: isFraud, dtype: float64

# %%
data["type"] = data["type"].map({"CASH_OUT": 1, "PAYMENT": 2,
                                 "CASH_IN": 3, "TRANSFER": 4,
                                 "DEBIT": 5})
data["isFraud"] = data["isFraud"].map({0: "No Fraud", 1: "Fraud"})
data.head()
# Out:
#    step  type    amount     nameOrig  oldbalanceOrg  newbalanceOrig  \
# 0     1     2   9839.64  C1231006815       170136.0       160296.36
# 1     1     2   1864.28  C1666544295        21249.0        19384.72
# 2     1     4    181.00  C1305486145          181.0            0.00
# 3     1     1    181.00   C840083671          181.0            0.00
# 4     1     2  11668.14  C2048537720        41554.0        29885.86
#
#       nameDest  oldbalanceDest  newbalanceDest   isFraud  isFlaggedFraud
# 0  M1979787155             0.0             0.0  No Fraud             0.0
# 1  M2044282225             0.0             0.0  No Fraud             0.0
# 2   C553264065             0.0             0.0     Fraud             0.0
# 3    C38997010         21182.0             0.0     Fraud             0.0
# 4  M1230701703             0.0             0.0  No Fraud             0.0

# %%
# splitting the data
from sklearn.model_selection import train_test_split

# Drop rows with NaN values before splitting
data_cleaned = data.dropna()

x = np.array(data_cleaned[["type", "amount", "oldbalanceOrg", "newbalanceOrig"]])
y = np.array(data_cleaned[["isFraud"]])

# %%
# training a machine learning model
from sklearn.tree import DecisionTreeClassifier
xtrain, xtest, ytrain, ytest = train_test_split(x, y, test_size=0.20, random_state=42)
model = DecisionTreeClassifier()
model.fit(xtrain, ytrain)
model.score(xtest, ytest)
# Out:
# 0.9992211635816091

# %%
# prediction
#features = [type, amount, oldbalanceOrg, newbalanceOrig]
features = np.array([[4, 9000.60, 9000.60, 0.0]])
print(model.predict(features))
# Out:
# ['Fraud']
